# %%
import ccxt

hitbtc   = ccxt.hitbtc({'verbose': True})

import json
hitbtc_markets = hitbtc.load_markets()
# Out:
# fetch Request: hitbtc GET https://api.hitbtc.com/api/2/public/currency RequestHeaders: {'User-Agent': 'python-requests/2.28.2', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'} RequestBody: None
#
# ...

# %%
print(hitbtc.id, len(hitbtc_markets))  # 1513
print(len(hitbtc.symbols)) # 1513 list of pairs

# print(json.dumps(hitbtc_markets, indent=4))  # return pairs details and prices
# print(json.dumps(hitbtc.fetch_order_book(hitbtc.symbols[219]), indent=4))  #BTC/USDT  returns orders 'Content-Length': '1686',
# print(hitbtc.fetch_ticker('BTC/USDT'))  # current price of pair
# print(hitbtc.fetch_trades('BTC/USDT'))  # Live time traders
# print(hitbtc.fetch_balance())  # Your cur balance, need API key
# print(hitbtc.id, hitbtc.create_market_sell_order('BTC/USD', 1))  # Sell BTC

# # limit buy BTC/EUR, you pay €2500 and receive ฿1  when the order is closed
# print(hitbtc.id, hitbtc.create_limit_buy_order('BTC/EUR', 1, 2500.00))  

# # pass/redefine custom exchange-specific order params: type, amount, price, flags, etc...
# hitbtc.create_market_buy_order('BTC/USD', 1, {'trading_agreement': 'agree'})
# Out:
# hitbtc 1513
# 1513
